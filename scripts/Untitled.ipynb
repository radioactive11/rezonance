# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %%
df = pd.read_csv("songs_2020.csv")
df.tail()
# Out:
#        Unnamed: 0                       name              spotify_id  \
# 97495       97495                  How It Go  4gfwOcBc4H5cl6wVBGu7h2
# 97496       97496                   Sunblind  308prODCCD0O660tIktbUi
# 97497       97497                     SKYBOX  7GwYENSg87oERcW0Wacd6m
# 97498       97498                       Cool  2nMOodYNHBAQ3Kc1QNimZU
# 97499       97499  Backseat (feat. PnB Rock)  0fj9oGrCKxVA4sXDxvbfiM
#
#        popularity
# 97495          66
# 97496          68
# 97497          67
# 97498          74
# 97499          71

# %%
df.drop(["Unnamed: 0"], axis=1, inplace=True)
df.head()
# Out:
#                                       name              spotify_id  popularity
# 0                   Mood (feat. iann dior)  3tjFYV6RSFtuktYl3ZtYcq         100
# 1     Laugh Now Cry Later (feat. Lil Durk)  2SAqBLGA283SUiwJ3xOUVI          95
# 2  For The Night (feat. Lil Baby & DaBaby)  0PvFJmanyNQMseIFrU708S          95
# 3             ROCKSTAR (feat. Roddy Ricch)  7ytR5pFWmSjzHJIeQkgog4          96
# 4                                 Lemonade  02kDW379Yfd5PzW5A6vuGt          94

# %%
df.hist(column = "popularity", bins=10, figsize=(16, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fba59f11bb0>]],
#       dtype=object)

# %%
df.drop(df[df["popularity"] < 75].index ,inplace=True, axis=0)
df.hist(column = "popularity", bins=10, figsize=(16, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fba3ab177f0>]],
#       dtype=object)

# %%
df.to_csv("2020.csv")

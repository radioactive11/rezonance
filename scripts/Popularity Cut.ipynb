# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %%
df = pd.read_csv("songs_2016.csv")
df.tail()
# Out:
#        Unnamed: 0                  name              spotify_id  popularity
# 97495       97495  Por Que Al Conocerte  4SfAYd9hmXBG1IrtoCbvhp          56
# 97496       97496            Stand Tall  25BSBxpCtoDbOpVd7cpqbw          53
# 97497       97497              Antidote  3CqMuOh8kuc4hrHZrvuDBc          54
# 97498       97498               Dive In  6LhGzSZlIGxZpyIXXZn9ZV          52
# 97499       97499   Now That We're Dead  01LODLnhlfNphZ366BqKc0          50

# %%
df.drop(["Unnamed: 0"], axis=1, inplace=True)
df.head()
# Out:
#                    name              spotify_id  popularity
# 0          I Fall Apart  75ZvA4QfFiZvzhj2xkaWAh          82
# 1  Say You Won't Let Go  5uCax9HTNlzGybIStD3vDh          85
# 2       Congratulations  3a1lNhkSLSkpJE4MSHpDu9          82
# 3               Redbone  0wXuerDYiBnERgIpbb3JBR          81
# 4               Starboy  7MXVkk9YMctZqd1Srtv4MB          83

# %%
df.hist(column = "popularity", bins=10, figsize=(16, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcbb913c460>]],
#       dtype=object)

# %%
df.drop(df[df["popularity"] < 60].index ,inplace=True, axis=0)
df.hist(column = "popularity", bins=10, figsize=(16, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcbb96d2af0>]],
#       dtype=object)

# %%
df.to_csv("year/2016.csv")

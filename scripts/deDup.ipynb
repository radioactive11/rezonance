# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("1980_to_2020.csv")
df.head()
# Out:
#                                       name              spotify_id  \
# 0                   Mood (feat. iann dior)  3tjFYV6RSFtuktYl3ZtYcq
# 1                          Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b
# 2                                 Dynamite  0t1kP63rueHleOhQkYSXFY
# 3             ROCKSTAR (feat. Roddy Ricch)  7ytR5pFWmSjzHJIeQkgog4
# 4  For The Night (feat. Lil Baby & DaBaby)  0PvFJmanyNQMseIFrU708S
#
#    popularity  artist  danceability  energy  loudness  mode  speechiness  \
# 0       100.0     NaN            -1      -1        -1    -1           -1
# 1        97.0     NaN            -1      -1        -1    -1           -1
# 2        97.0     NaN            -1      -1        -1    -1           -1
# 3        96.0     NaN            -1      -1        -1    -1           -1
# 4        95.0     NaN            -1      -1        -1    -1           -1
#
#    acousticness  instrumentalness  liveness  valence  preview  img
# ...

# %%
len(df)
# Out:
# 39851

# %%
df1 = df.iloc[:10000, :]
df1.to_csv("complete/p1.csv", index=False)

# %%
df2 = df.iloc[10000:20000, :]
df2.to_csv("complete/p2.csv", index=False)

# %%
df3 = df.iloc[20000:30000, :]
df3.to_csv("complete/p3.csv", index=False)

# %%
df4 = df.iloc[30000:, :]
df4.to_csv("complete/p4.csv", index=False)

# %%
df1.head()
# Out:
#                                       name              spotify_id  \
# 0                   Mood (feat. iann dior)  3tjFYV6RSFtuktYl3ZtYcq
# 1                          Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b
# 2                                 Dynamite  0t1kP63rueHleOhQkYSXFY
# 3             ROCKSTAR (feat. Roddy Ricch)  7ytR5pFWmSjzHJIeQkgog4
# 4  For The Night (feat. Lil Baby & DaBaby)  0PvFJmanyNQMseIFrU708S
#
#    popularity  artist  danceability  energy  loudness  mode  speechiness  \
# 0       100.0     NaN            -1      -1        -1    -1           -1
# 1        97.0     NaN            -1      -1        -1    -1           -1
# 2        97.0     NaN            -1      -1        -1    -1           -1
# 3        96.0     NaN            -1      -1        -1    -1           -1
# 4        95.0     NaN            -1      -1        -1    -1           -1
#
#    acousticness  instrumentalness  liveness  valence  preview  img
# ...

# %%
p1 = pd.read_csv("songs1.csv")
p1.head()
# Out:
#                                       name              spotify_id  \
# 0                   Mood (feat. iann dior)  3tjFYV6RSFtuktYl3ZtYcq
# 1                          Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b
# 2                                 Dynamite  0t1kP63rueHleOhQkYSXFY
# 3             ROCKSTAR (feat. Roddy Ricch)  7ytR5pFWmSjzHJIeQkgog4
# 4  For The Night (feat. Lil Baby & DaBaby)  0PvFJmanyNQMseIFrU708S
#
#    popularity      artist  danceability  energy  loudness  mode  speechiness  \
# 0       100.0    24kGoldn         0.700   0.722    -3.558     0       0.0369
# 1        97.0  The Weeknd         0.514   0.730    -5.934     1       0.0598
# 2        97.0         BTS         0.746   0.765    -4.410     0       0.0993
# 3        96.0      DaBaby         0.746   0.690    -7.956     1       0.1640
# 4        95.0   Pop Smoke         0.823   0.586    -6.606     0       0.2000
#
#    acousticness  instrumentalness  liveness  valence  \
# ...

# %%
p1.head()
# Out:
#                                       name              spotify_id  \
# 0                   Mood (feat. iann dior)  3tjFYV6RSFtuktYl3ZtYcq
# 1                          Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b
# 2                                 Dynamite  0t1kP63rueHleOhQkYSXFY
# 3             ROCKSTAR (feat. Roddy Ricch)  7ytR5pFWmSjzHJIeQkgog4
# 4  For The Night (feat. Lil Baby & DaBaby)  0PvFJmanyNQMseIFrU708S
#
#    popularity      artist  danceability  energy  loudness  mode  speechiness  \
# 0       100.0    24kGoldn         0.700   0.722    -3.558     0       0.0369
# 1        97.0  The Weeknd         0.514   0.730    -5.934     1       0.0598
# 2        97.0         BTS         0.746   0.765    -4.410     0       0.0993
# 3        96.0      DaBaby         0.746   0.690    -7.956     1       0.1640
# 4        95.0   Pop Smoke         0.823   0.586    -6.606     0       0.2000
#
#    acousticness  instrumentalness  liveness  valence  \
# ...

# %%
p1.isnull().sum()
# Out:
# name                   0
# spotify_id             0
# popularity             0
# artist                 1
# danceability           0
# energy                 0
# loudness               0
# mode                   0
# speechiness            0
# acousticness           0
# instrumentalness       0
# liveness               0
# valence                0
# preview             3415
# img                    3
# dtype: int64

# %%
p2 = pd.read_csv("songs2.csv")
p2.head()
# Out:
#                                   name              spotify_id  popularity  \
# 0                         Você Vai Ver  0jwGxgupGo2ovlU5eonF9D        61.0
# 1  Jesus Is The One (I Got Depression)  1YR9iNGXtsbrd8deR9ULDD        61.0
# 2                         Hate My Life  5zcLnqZbAjDGXX7HNcT1rE        61.0
# 3                         Mover Awayer  1yyIxshSIfW89EPTW0xkPH        61.0
# 4                               Habits  3KkWGDCb6byHjNYjxBihGK        61.0
#
#                       artist  danceability  energy  loudness  mode  \
# 0  Zezé Di Camargo & Luciano         0.739   0.575    -9.093     1
# 1                   Zack Fox         0.857   0.446   -12.778     1
# 2        Theory of a Deadman         0.508   0.828    -4.065     1
# 3               Hobo Johnson         0.703   0.636    -5.737     0
# 4                        NAV         0.750   0.534    -7.004     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
mask = p2["name"].str.contains("Duele Verte", case=False, regex=False)
p2[mask]
# Out:
#              name              spotify_id  popularity          artist  \
# 2100  Duele Verte  0BGjGnyzTgdLi1zxnsMGDc        59.0  Ricardo Arjona
#
#       danceability  energy  loudness  mode  speechiness  acousticness  \
# 2100          0.75   0.779    -4.389     1        0.073         0.317
#
#       instrumentalness  liveness  valence  \
# 2100               0.0    0.0567    0.601
#
#                                                 preview  \
# 2100  https://p.scdn.co/mp3-preview/a7bbed0f3a47b746...
#
#                                                     img
# 2100  https://i.scdn.co/image/ab67616d0000b27367fc21...

# %%
p2.iloc[3100, :]
# Out:
# name                                                       Impossible
# spotify_id                                     473xAny4InLJTlWnUNEwZq
# popularity                                                         58
# artist                                                       Manafest
# danceability                                                    0.453
# energy                                                          0.898
# loudness                                                       -3.132
# mode                                                                1
# speechiness                                                     0.108
# acousticness                                                  0.00877
# instrumentalness                                                    0
# liveness                                                        0.136
# valence                                                         0.525
# ...

# %%
p2.isnull().sum()
# Out:
# name                   0
# spotify_id             0
# popularity             0
# artist                 0
# danceability           0
# energy                 0
# loudness               0
# mode                   0
# speechiness            0
# acousticness           0
# instrumentalness       0
# liveness               0
# valence                0
# preview             3227
# img                    0
# dtype: int64

# %%
p4 = pd.read_csv("songs4.csv")
p4.tail()
# Out:
#                                                 name              spotify_id  \
# 9846                                   El Testamento  3nbUUqHc3uealIb8RYDPAg
# 9847  Can't Let You Go (feat. Mike Shorey & Lil' Mo)  7HTI8XgkwHpq2Imw6kU6RE
# 9848                                      Mood Rings  6Cc4Nc2WcDsGSx19LxOivK
# 9849                                       P-Poppin'  6yOghbMYTTUdOGiExT0rIF
# 9850                                     Sana Maulit                     NaN
#
#       popularity      artist  danceability  energy  loudness  mode  \
# 9846        40.0  Rigo Tovar         0.637   0.872    -4.799     1
# 9847        40.0    Fabolous         0.534   0.693    -6.049     1
# 9848        40.0   Relient K         0.589   0.790    -5.372     1
# 9849        40.0    Ludacris         0.907   0.831    -5.291     1
# 9850         NaN         NaN        -1.000  -1.000    -1.000    -1
#
#       speechiness  acousticness  instrumentalness  liveness  valence  preview  \
# ...

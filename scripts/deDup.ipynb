# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("songs.csv")
df.head()
# Out:
#                                       name              spotify_id  \
# 0                   Mood (feat. iann dior)  3tjFYV6RSFtuktYl3ZtYcq
# 1                          Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b
# 2                                 Dynamite  0t1kP63rueHleOhQkYSXFY
# 3             ROCKSTAR (feat. Roddy Ricch)  7ytR5pFWmSjzHJIeQkgog4
# 4  For The Night (feat. Lil Baby & DaBaby)  0PvFJmanyNQMseIFrU708S
#
#    popularity artist  danceability  energy  loudness  mode  speechiness  \
# 0       100.0    NaN          -1.0    -1.0      -1.0    -1         -1.0
# 1        97.0    NaN          -1.0    -1.0      -1.0    -1         -1.0
# 2        97.0    NaN          -1.0    -1.0      -1.0    -1         -1.0
# 3        96.0    NaN          -1.0    -1.0      -1.0    -1         -1.0
# 4        95.0    NaN          -1.0    -1.0      -1.0    -1         -1.0
#
#    acousticness  instrumentalness  liveness  valence preview  img
# 0          -1.0              -1.0      -1.0     -1.0     NaN  NaN
# 1          -1.0              -1.0      -1.0     -1.0     NaN  NaN
# 2          -1.0              -1.0      -1.0     -1.0     NaN  NaN
# 3          -1.0              -1.0      -1.0     -1.0     NaN  NaN
# 4          -1.0              -1.0      -1.0     -1.0     NaN  NaN

# %%
df.tail()
# Out:
#                                      name              spotify_id  popularity  \
# 39991              Tu Y Yo - Cumbia Remix  5ZYR17P7sT73hcIMn9tmZ8        46.0
# 39992                     Mi Pequeño Amor  44vo3BDIwGHl0oxr4m8bM1        46.0
# 39993                       I Like To Win  1Q3a0PAwpm8TRq1VvbVLgY        46.0
# 39994                     Desde Que Te Ví  50I2hZeQ1tiPE8zvkFkQsM        46.0
# 39995  Amantes Inocentes - Version Balada  6Jn8zqh19yyRgZlAsz0rNL        46.0
#
#       artist  danceability  energy  loudness  mode  speechiness  acousticness  \
# 39991    NaN          -1.0    -1.0      -1.0    -1         -1.0          -1.0
# 39992    NaN          -1.0    -1.0      -1.0    -1         -1.0          -1.0
# 39993    NaN          -1.0    -1.0      -1.0    -1         -1.0          -1.0
# 39994    NaN          -1.0    -1.0      -1.0    -1         -1.0          -1.0
# 39995    NaN          -1.0    -1.0      -1.0    -1         -1.0          -1.0
#
#        instrumentalness  liveness  valence preview  img
# 39991              -1.0      -1.0     -1.0     NaN  NaN
# 39992              -1.0      -1.0     -1.0     NaN  NaN
# 39993              -1.0      -1.0     -1.0     NaN  NaN
# 39994              -1.0      -1.0     -1.0     NaN  NaN
# 39995              -1.0      -1.0     -1.0     NaN  NaN

# %%
mask = (df["name"].str.contains("payphon", regex=False, case=False))
df[mask]
# Out:
#                   name              spotify_id  popularity artist  \
# 1726          Payphone  1LmN9SSHISbtp9LoaR5ZVJ        74.0    NaN
# 28247         Payphone  4P0osvTXoSYZZC2n8IFH3c        52.0    NaN
# 36538         Payphone  2wNQm6zXDZTz1xrQbA78A5        48.0    NaN
# 37456  Payphone - Edit  4cdgQp78RyRzI04Bmw8o44        47.0    NaN
#
#        danceability  energy  loudness  mode  speechiness  acousticness  \
# 1726           -1.0    -1.0      -1.0    -1         -1.0          -1.0
# 28247          -1.0    -1.0      -1.0    -1         -1.0          -1.0
# 36538          -1.0    -1.0      -1.0    -1         -1.0          -1.0
# 37456          -1.0    -1.0      -1.0    -1         -1.0          -1.0
#
#        instrumentalness  liveness  valence preview  img
# 1726               -1.0      -1.0     -1.0     NaN  NaN
# 28247              -1.0      -1.0     -1.0     NaN  NaN
# 36538              -1.0      -1.0     -1.0     NaN  NaN
# 37456              -1.0      -1.0     -1.0     NaN  NaN

# %%
df.iloc[7030:7040, :]
# Out:
#                                     name              spotify_id  popularity  \
# 7030                   You Can't Save Me  5LKzqs734Xs528hqK8bGS1        65.0
# 7031                       Stubborn Love  3ekNuTF3UpOvIZCfiejpnC        65.0
# 7032                  Schlechtes Vorbild  2L2NmbpVp1dHotlpVJ4zr8        65.0
# 7033                             Burning  68vxG1i6RSmrsY9mRdqDgG        65.0
# 7034                      2z Don Corleon  5DoPoFpGLfEu9KyhbGULMB        65.0
# 7035                       She’s The One  3zM2prB16NRn1zggh1KCY0        65.0
# 7036                        Anime Thighs  3wn5Rw7VBqwP0vAQtjMhOS        65.0
# 7037    Eres para Mí (with Anita Tijoux)  4m3vLNZkFAjm30XxPXf7E3        65.0
# 7038                           Açaí Bowl  5M3KOe4FGUidvRDUbFFdFk        65.0
# 7039  There's Still A Light In The House  4MIPNDbxVPWdLwH6A4nsiY        65.0
#
#              artist  danceability  energy  loudness  mode  speechiness  \
# 7030            SiR         0.623   0.585    -7.895     1       0.1240
# 7031  The Lumineers         0.598   0.560   -11.679     1       0.0375
# 7032           Sido         0.942   0.613    -7.649     1       0.1130
# 7033  Maggie Rogers         0.735   0.688    -5.471     1       0.1040
# 7034         Lil 2z         0.847   0.444   -10.167     0       0.4920
# 7035     Juice WRLD         0.621   0.804    -5.502     0       0.2250
# 7036     MC Virgins        -1.000  -1.000    -1.000    -1      -1.0000
# 7037            NaN        -1.000  -1.000    -1.000    -1      -1.0000
# 7038            NaN        -1.000  -1.000    -1.000    -1      -1.0000
# 7039            NaN        -1.000  -1.000    -1.000    -1      -1.0000
#
#       acousticness  instrumentalness  liveness  valence  \
# 7030        0.0628          0.000155    0.1190    0.538
# 7031        0.6070          0.043200    0.1960    0.221
# 7032        0.1840          0.000003    0.2640    0.961
# 7033        0.2100          0.000031    0.1060    0.282
# 7034        0.3360          0.000000    0.0996    0.667
# 7035        0.3080          0.000000    0.2970    0.396
# 7036       -1.0000         -1.000000   -1.0000   -1.000
# 7037       -1.0000         -1.000000   -1.0000   -1.000
# 7038       -1.0000         -1.000000   -1.0000   -1.000
# 7039       -1.0000         -1.000000   -1.0000   -1.000
#
#                                                 preview  \
# 7030  https://i.scdn.co/image/ab67616d0000b273bbee54...
# 7031  https://i.scdn.co/image/ab67616d0000b273424143...
# 7032  https://i.scdn.co/image/ab67616d0000b273d74a7c...
# 7033  https://i.scdn.co/image/ab67616d0000b273d658a0...
# 7034  https://i.scdn.co/image/ab67616d0000b27308e41d...
# 7035  https://i.scdn.co/image/ab67616d0000b273af149e...
# 7036                                                NaN
# 7037                                                NaN
# 7038                                                NaN
# 7039                                                NaN
#
#                                                     img
# 7030  https://p.scdn.co/mp3-preview/65cf0682c523ec2b...
# 7031  https://p.scdn.co/mp3-preview/d1e9a3b8997489ce...
# 7032  https://p.scdn.co/mp3-preview/3a0b951ec1f6c4be...
# 7033                                                NaN
# 7034  https://p.scdn.co/mp3-preview/2c9043fa3048589f...
# 7035                                                NaN
# 7036                                                NaN
# 7037                                                NaN
# 7038                                                NaN
# 7039                                                NaN

# %%
df.sort_values(by="popularity", inplace=True)

# %%
df["artist"] = ""
df["danceability"] = -1
df["energy"] = -1
df["loudness"] = -1
df["mode"] =  -1
df["speechiness"] = -1
df["acousticness"] = -1
df["instrumentalness"] = -1
df["liveness"] = -1
df["valence"] = -1
df["preview"] = ""
df["img"] = ""

# %%
df.head()

# %%
df.iloc[0, 3]

# %%
df.to_csv("1980_to_2020.csv", index=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats

set_matplotlib_formats('retina')

# %%
songs = pd.read_csv("raw/songs_2009.csv")
len(songs)
# Out:
# 97450

# %%
songs.drop_duplicates(subset="spotify_id", keep='first', inplace=True)
len(songs)
# Out:
# 1999

# %%
songs.drop(["Unnamed: 0"], inplace=True, axis=1)
songs.head()
# Out:
#                                name              spotify_id  popularity
# 0                When I Look At You  7ywzEdEuVG1lsjsRCGJfLy          73
# 1          Day 'N' Nite (nightmare)  5FEXPoPnzueFJQCPRIrC3c          73
# 2      Ain't No Rest for the Wicked  3Pzh926pXggbMe2ZpXyMV7          74
# 3                         Fireflies  3DamFFqW32WihKkTVlwTYQ          79
# 4  Pursuit Of Happiness (Nightmare)  5iSEsR6NKjlC9SrIJkyL3k          72

# %%
mask = songs["name"].str.contains("hello", case=False, regex=False)
songs[mask]
# Out:
#                 name              spotify_id  popularity
# 54599          Hello  7wuY9kPzREAC9OR7KScoli          52
# 55999  Hello Seattle  6kIpxmFQ35wgI3cK77LKbx          47
# 96949  Hello Seattle  2bZwRGh8kmVhtsBnDjv14Z          42

# %%
songs.hist(column = "popularity", bins=10, figsize=(16, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb68fd48dc0>]],
#       dtype=object)

# %%
songs.drop(songs[(songs["popularity"] < 45)].index, axis=0, inplace=True)

# %%
songs.to_csv("processed/2009.csv")

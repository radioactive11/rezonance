# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %%
songs = pd.read_csv("songs_2010.csv")
len(songs)
# Out:
# 97500

# %%
songs.drop_duplicates(subset="spotify_id", keep='first', inplace=True)
len(songs)
# Out:
# 1999

# %%
songs.drop(["Unnamed: 0"], inplace=True, axis=1)
songs.head()
# Out:
#                                   name              spotify_id  popularity
# 0  No Hands (feat. Roscoe Dash & Wale)  03tqyYWC9Um2ZqU0ZN849H          76
# 1                 Just the Way You Are  7BqBn9nzAq8spo5e7cZ0dJ          80
# 2                     Dirt Road Anthem  2qYsSHsYkihWx043HVJQRV          73
# 3                 Love The Way You Lie  15JINEqzVMv3SvJTAXAKED          81
# 4                              TiK ToK  0HPD5WQqrq7wPWR7P7Dw1i          80

# %%
mask = songs["name"].str.contains("hello", case=False, regex=False)
songs[mask]
# Out:
#                              name              spotify_id  popularity
# 19749    Hello (feat. Dragonette)  3sl4dcqSwxHVnLfqwF2jly          57
# 61449  Hello Good Morning - Remix  2uAbEJGrLecIbkW9p3OqQl          44
# 90249          Hello Good Morning  7yzSijmAyOMBcHrK6Tfsoe          47
# 92449                 Hello World  2zdltIgwTAWGXHHJGTPKqv          45

# %%
songs.hist(column = "popularity", bins=10, figsize=(16, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc1a47ded30>]],
#       dtype=object)

# %%
songs.drop(songs[(songs["popularity"] <45)].index, axis=0, inplace=True)

# %%
songs.to_csv("processed/2010.csv")

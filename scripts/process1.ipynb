# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats

set_matplotlib_formats('retina')

# %%
songs = pd.read_csv("raw/songs_1989.csv")
len(songs)
# Out:
# 96981

# %%
songs.drop_duplicates(subset="spotify_id", keep='first', inplace=True)
len(songs)
# Out:
# 1989

# %%
songs.drop(["Unnamed: 0"], inplace=True, axis=1)
songs.head()
# Out:
#                          name              spotify_id  popularity
# 0         Sweet Child O' Mine  7snQQk1zcKl8gZ92AnueZW        73.0
# 1       Welcome To The Jungle  0G21yYKMZoHa30cYVi1iA8        72.0
# 2  Everywhere - 2017 Remaster  254bXAqt3zP6P50BdQvEsq        79.0
# 3               Paradise City  6eN1f9KNmiWEhpE2RhQqB5        72.0
# 4     Never Gonna Give You Up  7GhIk7Il098yCjg4BQjzvb        68.0

# %%
mask = songs["name"].str.contains("hello", case=False, regex=False)
songs[mask]
# Out:
#                 name              spotify_id  popularity
# 33399  Hello Vietnam  22VgNtkpp5gXf44IAmp3HL        42.0

# %%
songs.hist(column = "popularity", bins=10, figsize=(16, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8d6707afa0>]],
#       dtype=object)

# %%
songs.drop(songs[(songs["popularity"] < 50)].index, axis=0, inplace=True)

# %%
songs.to_csv("processed/1987.csv")

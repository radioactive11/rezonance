# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats

set_matplotlib_formats('retina')

# %%
songs = pd.read_csv("raw/songs_1991.csv")
len(songs)
# Out:
# 97500

# %%
songs.drop_duplicates(subset="spotify_id", keep='first', inplace=True)
len(songs)
# Out:
# 1999

# %%
songs.drop(["Unnamed: 0"], inplace=True, axis=1)
songs.head()
# Out:
#                       name              spotify_id  popularity
# 0  Smells Like Teen Spirit  5ghIJDpPoe3CfHMGu71E6T          74
# 1         Under the Bridge  3d9DChrdc6BOeFsbrZ3Is0          81
# 2          Come As You Are  4P5KoWXOxwuobLmHXLMobV          72
# 3     Nothing Else Matters  10igKaIKsSB6ZnWxPxPvKO          69
# 4                Even Flow  6QewNVIDKdSl8Y3ycuHIei          75

# %%
mask = songs["name"].str.contains("hello", case=False, regex=False)
songs[mask]
# Out:
# Empty DataFrame
# Columns: [name, spotify_id, popularity]
# Index: []

# %%
songs.hist(column = "popularity", bins=10, figsize=(16, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc9146559d0>]],
#       dtype=object)

# %%
songs.drop(songs[(songs["popularity"] < 45)].index, axis=0, inplace=True)

# %%
songs.to_csv("processed/1991.csv")
